# %%
import pandas as pd

# %%
df = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/direccion-general-de-estadisticas-y-censos/encuesta-anual-hogares/encuesta-anual-hogares-2019.csv",
                 encoding="latin1")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14319 entries, 0 to 14318
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           14319 non-null  int64
#  1   nhogar                       14319 non-null  int64
#  2   miembro                      14319 non-null  int64
#  3   comuna                       14319 non-null  int64
#  4   dominio                      14319 non-null  object
#  5   edad                         14319 non-null  int64
#  6   sexo                         14319 non-null  object
#  7   parentesco_jefe              14319 non-null  object
#  8   situacion_conyugal           14318 non-null  object
#  9   num_miembro_padre            14319 non-null  object
#  10  num_miembro_madre            14319 non-null  object
#  11  estado_ocupacional           14319 non-null  object
#  12  cat_ocupacional              14319 non-null  object
# ...

# %%
df.head()
# Out:
#    id  nhogar  miembro  comuna             dominio  edad   sexo  \
# 0   1       1        1       5  Resto de la Ciudad    18  Mujer
# 1   1       1        2       5  Resto de la Ciudad    18  Mujer
# 2   2       1        1       2  Resto de la Ciudad    18  Varon
# 3   2       1        2       2  Resto de la Ciudad    50  Mujer
# 4   2       1        3       2  Resto de la Ciudad    17  Varon
#
#         parentesco_jefe situacion_conyugal          num_miembro_padre  ...  \
# 0                  Jefe          Soltero/a  Padre no vive en el hogar  ...
# 1      Otro no familiar          Soltero/a  Padre no vive en el hogar  ...
# 2                  Jefe          Soltero/a  Padre no vive en el hogar  ...
# 3  Padre/Madre/Suegro/a            Viudo/a             No corresponde  ...
# 4         Otro familiar          Soltero/a  Padre no vive en el hogar  ...
#
#   ingreso_per_capita_familiar        estado_educativo   sector_educativo  \
# ...

# %%
df.dtypes.value_counts()
# Out:
# object    21
# int64     10
# dtype: int64

# %%
Val_Nulos = round(Val_Nulos/df.shape[0]*100,2)
Val_Nulos
# Out:
# hijos_nacidos_vivos    0.38
# nivel_max_educativo    0.05
# años_escolaridad       0.00
# afiliacion_salud       0.00
# sector_educativo       0.00
# situacion_conyugal     0.00
# lugar_nacimiento       0.00
# dtype: float64

# %%
Cat_Colum = df.select_dtypes(include='object').columns.to_list()
Cat_Colum
# Out:
# ['dominio',
#  'sexo',
#  'parentesco_jefe',
#  'situacion_conyugal',
#  'num_miembro_padre',
#  'num_miembro_madre',
#  'estado_ocupacional',
#  'cat_ocupacional',
#  'calidad_ingresos_lab',
#  'calidad_ingresos_no_lab',
#  'calidad_ingresos_totales',
#  'calidad_ingresos_familiares',
#  'estado_educativo',
#  'sector_educativo',
#  'nivel_actual',
#  'nivel_max_educativo',
#  'años_escolaridad',
#  'lugar_nacimiento',
#  'afiliacion_salud',
#  'hijos_nacidos_vivos',
#  'cantidad_hijos_nac_vivos']

# %%
new_list=[]
for x in Cat_Colum: # Cat_Colum lo definiste arriba si pusiste otro nombre cambiar aqui
  new_list.append((x, len(df[x].unique()), df[x].unique()))

pd.DataFrame(new_list, columns=['Feature', 'cantidad valores unicos', 'valores']).sort_values('cantidad valores unicos', ascending=False)
# Out:
#                         Feature  cantidad valores unicos  \
# 16             años_escolaridad                       21
# 20     cantidad_hijos_nac_vivos                       14
# 14                 nivel_actual                       14
# 5             num_miembro_madre                       11
# 2               parentesco_jefe                        9
# 4             num_miembro_padre                        9
# 3            situacion_conyugal                        8
# 17             lugar_nacimiento                        8
# 15          nivel_max_educativo                        8
# 18             afiliacion_salud                        6
# 13             sector_educativo                        5
# 7               cat_ocupacional                        5
# 10     calidad_ingresos_totales                        4
# 9       calidad_ingresos_no_lab                        4
# 8          calidad_ingresos_lab                        4
# ...

# %%
import seaborn as sns
sns.heatmap(df[col].corr(), annot=True).set(title='Correlación de Pearson en varialbes numericas');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-4c7c32aacc45> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.heatmap(df[col].corr(), annot=True).set(title='Correlación de Pearson en varialbes numericas');
#
# NameError: name 'col' is not defined
